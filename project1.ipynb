# %%
import pandas as pd

# %%
df1=pd.read_csv('trial.csv')
df2=pd.read_csv('audit.csv')

# %%
df1.shape
# Out:
# (776, 18)

# %%
df1.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  SCORE_A  PARA_B  SCORE_B  TOTAL  numbers  \
# 0          3.89          23    4.18        6    2.50        2   6.68      5.0
# 1          3.89           6    0.00        2    4.83        2   4.83      5.0
# 2          3.89           6    0.51        2    0.23        2   0.74      5.0
# 3          3.89           6    0.00        2   10.80        6  10.80      6.0
# 4          3.89           6    0.00        2    0.08        2   0.08      5.0
#
#    Marks  Money_Value  MONEY_Marks  District  Loss  LOSS_SCORE  History  \
# 0      2         3.38            2         2     0           2        0
# 1      2         0.94            2         2     0           2        0
# 2      2         0.00            2         2     0           2        0
# 3      6        11.75            6         2     0           2        0
# 4      2         0.00            2         2     0           2        0
#
#    History_score  Score  Risk
# 0              2    2.4     1
# ...

# %%
df2.shape
# Out:
# (776, 27)

# %%
df2.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          23    4.18      0.6   2.508    2.50      0.2   0.500
# 1          3.89           6    0.00      0.2   0.000    4.83      0.2   0.966
# 2          3.89           6    0.51      0.2   0.102    0.23      0.2   0.046
# 3          3.89           6    0.00      0.2   0.000   10.80      0.6   6.480
# 4          3.89           6    0.00      0.2   0.000    0.08      0.2   0.016
#
#    TOTAL  numbers  ...   RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   6.68      5.0  ...      0.4        0   0.2     0.0    2.4          8.574
# 1   4.83      5.0  ...      0.4        0   0.2     0.0    2.0          2.554
# 2   0.74      5.0  ...      0.4        0   0.2     0.0    2.0          1.548
# 3  10.80      6.0  ...      0.4        0   0.2     0.0    4.4         17.530
# 4   0.08      5.0  ...      0.4        0   0.2     0.0    2.0          1.416
#
# ...

# %%
df1.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'SCORE_A', 'PARA_B', 'SCORE_B',
#        'TOTAL', 'numbers', 'Marks', 'Money_Value', 'MONEY_Marks', 'District',
#        'Loss', 'LOSS_SCORE', 'History', 'History_score', 'Score', 'Risk'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E',
#        'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
df3=df1

# %%
lis1=df1.columns
lis2=df2.columns

# %%
for col in lis1:
    if col in lis2:
        del df3[col]

# %%
df3.shape
# Out:
# (776, 8)

# %%
df3.head()
# Out:
#    SCORE_A  SCORE_B  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  \
# 0        6        2      2            2         2     0           2
# 1        2        2      2            2         2     0           2
# 2        2        2      2            2         2     0           2
# 3        2        6      6            6         2     0           2
# 4        2        2      2            2         2     0           2
#
#    History_score
# 0              2
# 1              2
# 2              2
# 3              2
# 4              2

# %%
df2.head()
# Out:
#    Sector_score LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B  Risk_B  \
# 0          3.89          23    4.18      0.6   2.508    2.50      0.2   0.500
# 1          3.89           6    0.00      0.2   0.000    4.83      0.2   0.966
# 2          3.89           6    0.51      0.2   0.102    0.23      0.2   0.046
# 3          3.89           6    0.00      0.2   0.000   10.80      0.6   6.480
# 4          3.89           6    0.00      0.2   0.000    0.08      0.2   0.016
#
#    TOTAL  numbers  ...   RiSk_E  History  Prob  Risk_F  Score  Inherent_Risk  \
# 0   6.68      5.0  ...      0.4        0   0.2     0.0    2.4          8.574
# 1   4.83      5.0  ...      0.4        0   0.2     0.0    2.0          2.554
# 2   0.74      5.0  ...      0.4        0   0.2     0.0    2.0          1.548
# 3  10.80      6.0  ...      0.4        0   0.2     0.0    4.4         17.530
# 4   0.08      5.0  ...      0.4        0   0.2     0.0    2.0          1.416
#
# ...

# %%
df3.columns
# Out:
# Index(['SCORE_A', 'SCORE_B', 'Marks', 'MONEY_Marks', 'District', 'Loss',
#        'LOSS_SCORE', 'History_score'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Sector_score', 'LOCATION_ID', 'PARA_A', 'Score_A', 'Risk_A', 'PARA_B',
#        'Score_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'District_Loss', 'PROB', 'RiSk_E',
#        'History', 'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk', 'Audit_Risk', 'Risk'],
#       dtype='object')

# %%
#SCORE_A in df3 is same as Score_A in df2 the only difference is 
#SCORE_A is scaled by a factor of 10
#same for SCORE_B and Score_B
#so before combining dataframes

# %%
del df2['Score_A']
del df2['Score_B']

# %%
df=pd.concat([df3,df2],axis=1)

# %%
df.head()
# Out:
#    SCORE_A  SCORE_B  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  \
# 0        6        2      2            2         2     0           2
# 1        2        2      2            2         2     0           2
# 2        2        2      2            2         2     0           2
# 3        2        6      6            6         2     0           2
# 4        2        2      2            2         2     0           2
#
#    History_score  Sector_score LOCATION_ID  ...   RiSk_E  History  Prob  \
# 0              2          3.89          23  ...      0.4        0   0.2
# 1              2          3.89           6  ...      0.4        0   0.2
# 2              2          3.89           6  ...      0.4        0   0.2
# 3              2          3.89           6  ...      0.4        0   0.2
# 4              2          3.89           6  ...      0.4        0   0.2
#
#    Risk_F  Score  Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  \
# ...

# %%
#now let's look at District,loss and District_loss

# %%
loss_df=df[['District','Loss','LOSS_SCORE','District_Loss']]

# %%
loss_df.describe()
# Out:
#          District        Loss  LOSS_SCORE  District_Loss
# count  776.000000  776.000000  776.000000     776.000000
# mean     2.505155    0.029639    2.061856       2.505155
# std      1.228678    0.184280    0.375080       1.228678
# min      2.000000    0.000000    2.000000       2.000000
# 25%      2.000000    0.000000    2.000000       2.000000
# 50%      2.000000    0.000000    2.000000       2.000000
# 75%      2.000000    0.000000    2.000000       2.000000
# max      6.000000    2.000000    6.000000       6.000000

# %%
#seems like District and District_Loss are very similar

# %%
df['District'].equals(df['District_Loss'])
# Out:
# True

# %%
del df['District_Loss']

# %%
df.head()
# Out:
#    SCORE_A  SCORE_B  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  \
# 0        6        2      2            2         2     0           2
# 1        2        2      2            2         2     0           2
# 2        2        2      2            2         2     0           2
# 3        2        6      6            6         2     0           2
# 4        2        2      2            2         2     0           2
#
#    History_score  Sector_score LOCATION_ID  ...   RiSk_E  History  Prob  \
# 0              2          3.89          23  ...      0.4        0   0.2
# 1              2          3.89           6  ...      0.4        0   0.2
# 2              2          3.89           6  ...      0.4        0   0.2
# 3              2          3.89           6  ...      0.4        0   0.2
# 4              2          3.89           6  ...      0.4        0   0.2
#
#    Risk_F  Score  Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  \
# ...

# %%
df.shape
# Out:
# (776, 32)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 776 entries, 0 to 775
# Data columns (total 32 columns):
# SCORE_A           776 non-null int64
# SCORE_B           776 non-null int64
# Marks             776 non-null int64
# MONEY_Marks       776 non-null int64
# District          776 non-null int64
# Loss              776 non-null int64
# LOSS_SCORE        776 non-null int64
# History_score     776 non-null int64
# Sector_score      776 non-null float64
# LOCATION_ID       776 non-null object
# PARA_A            776 non-null float64
# Risk_A            776 non-null float64
# PARA_B            776 non-null float64
# Risk_B            776 non-null float64
# TOTAL             776 non-null float64
# numbers           776 non-null float64
# Score_B.1         776 non-null float64
# Risk_C            776 non-null float64
# Money_Value       775 non-null float64
# Score_MV          776 non-null float64
# Risk_D            776 non-null float64
# PROB              776 non-null float64
# ...

# %%
df['Money_Value'].value_counts()
# Out:
# 0.00      332
# 0.04       11
# 0.02        9
# 0.06        8
# 0.11        7
# 0.05        7
# 0.01        6
# 0.10        5
# 0.03        4
# 0.19        4
# 0.07        4
# 0.58        4
# 0.22        3
# 6.96        3
# 0.43        3
# 0.57        3
# 0.76        3
# 0.18        3
# 0.33        3
# 0.09        3
# 0.74        3
# 0.13        3
# 0.28        3
# 0.20        3
# 0.32        3
# 0.51        3
# 0.72        2
# 0.82        2
# 0.67        2
# 5.41        2
#          ...
# 2.44        1
# 0.80        1
# 80.80       1
# 27.99       1
# 19.68       1
# 10.65       1
# 7.78        1
# 3.42        1
# 0.23        1
# 5.37        1
# 0.44        1
# 85.05       1
# 47.90       1
# 52.13       1
# 0.29        1
# 145.97      1
# 0.84        1
# 1.19        1
# 9.53        1
# 10.02       1
# 5.58        1
# 0.96        1
# 27.28       1
# 57.16       1
# 43.53       1
# 6.78        1
# 27.10       1
# 1.08        1
# 16.03       1
# 98.75       1
# ...

# %%
df['Money_Value'].fillna((df['Money_Value'].mean()),inplace=True)

# %%
df.head()
# Out:
#    SCORE_A  SCORE_B  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  \
# 0        6        2      2            2         2     0           2
# 1        2        2      2            2         2     0           2
# 2        2        2      2            2         2     0           2
# 3        2        6      6            6         2     0           2
# 4        2        2      2            2         2     0           2
#
#    History_score  Sector_score LOCATION_ID  ...   RiSk_E  History  Prob  \
# 0              2          3.89          23  ...      0.4        0   0.2
# 1              2          3.89           6  ...      0.4        0   0.2
# 2              2          3.89           6  ...      0.4        0   0.2
# 3              2          3.89           6  ...      0.4        0   0.2
# 4              2          3.89           6  ...      0.4        0   0.2
#
#    Risk_F  Score  Inherent_Risk  CONTROL_RISK  Detection_Risk  Audit_Risk  \
# ...

# %%
#Audit_Risk for Regression task and Risk for Classification Task

# %%
df_reg=df#for regression task
df_clf=df
df_pca=df

# %%
y_reg=df['Audit_Risk']
y_clf=df['Risk']

# %%
del df_reg['Risk']

# %%
X=df_reg
del df_reg['Audit_Risk']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y_reg, test_size=0.30, random_state=42)
X_train1, X_test1, y_train1, y_test1 = train_test_split( X, y_clf, test_size=0.30, random_state=42)

# %%
x1=pd.concat([X_train, y_train], axis=1)
x1.shape
# Out:
# (543, 31)

# %%
x1.head()
# Out:
#      SCORE_A  SCORE_B  Marks  MONEY_Marks  District  Loss  LOSS_SCORE  \
# 335        2        2      2            2         2     0           2
# 110        6        2      2            2         2     0           2
# 82         2        2      2            2         2     0           2
# 51         2        6      2            2         2     0           2
# 763        2        2      2            2         2     0           2
#
#      History_score  Sector_score LOCATION_ID     ...      PROB  RiSk_E  \
# 335              2          2.37          32     ...       0.2     0.4
# 110              2          3.89          13     ...       0.2     0.4
# 82               2          3.89           2     ...       0.2     0.4
# 51               2          3.89          22     ...       0.2     0.4
# 763              2         55.57          36     ...       0.2     0.4
#
#      History  Prob  Risk_F  Score  Inherent_Risk  CONTROL_RISK  \
# ...

# %%
import numpy as np
import re
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
colormap = plt.cm.RdBu
plt.figure(figsize=(20,18))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(x1.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
lis_x=X_train.columns
from sklearn.ensemble import RandomForestRegressor
rnd_clf = RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=42)
rnd_clf.fit(X_train, y_train)
for name, score in zip(lis_x, rnd_clf.feature_importances_):
    print(name, score)
# Out:
# SCORE_A 0.00021320358135441166
# SCORE_B 0.0007503393218935435
# Marks 0.00018685361384479485
# MONEY_Marks 3.915436978887125e-05
# District 0.0010800671682264687
# Loss 0.00015797865076296952
# LOSS_SCORE 4.207702835426565e-05
# History_score 0.007062407907005087
# Sector_score 0.003316386005366991
# LOCATION_ID 0.006112627307082167
# PARA_A 0.008717518010422247
# Risk_A 0.004346087219185464
# PARA_B 0.1316621724660272
# Risk_B 0.10765573270444202
# TOTAL 0.1444314375689774
# numbers 0.0016910142003312466
# Score_B.1 0.0007713627693597736
# Risk_C 0.0006575745425423299
# Money_Value 0.0598557125321833
# Score_MV 4.1769950148528045e-05
# Risk_D 0.05589608364206396
# PROB 9.752246288818636e-05
# RiSk_E 0.005796373161618581
# History 0.011734722550352409
# Prob 0.003526877701144353
# Risk_F 0.009033362492891432
# Score 0.015178465410736202
# Inherent_Risk 0.36660670146875024
# CONTROL_RISK 0.05333841419225541
# Detection_Risk 0.0

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(16,6)) 
plt.plot(rnd_clf.feature_importances_)
plt.xticks(np.arange(X_train.shape[1]), X_train.columns.tolist(), rotation=90);

# %%
numerical_feats=X_train.dtypes[X_train.dtypes!='object'].index
categorical_feats=X_train.dtypes[X_train.dtypes=='object'].index

# %%
numerical_feats
# Out:
# Index(['SCORE_A', 'SCORE_B', 'Marks', 'MONEY_Marks', 'District', 'Loss',
#        'LOSS_SCORE', 'History_score', 'Sector_score', 'PARA_A', 'Risk_A',
#        'PARA_B', 'Risk_B', 'TOTAL', 'numbers', 'Score_B.1', 'Risk_C',
#        'Money_Value', 'Score_MV', 'Risk_D', 'PROB', 'RiSk_E', 'History',
#        'Prob', 'Risk_F', 'Score', 'Inherent_Risk', 'CONTROL_RISK',
#        'Detection_Risk'],
#       dtype='object')

# %%
categorical_feats
# Out:
# Index(['LOCATION_ID'], dtype='object')

# %%
#clearly location ID is of no use as from correlation matrix and random forest regressor importance

# %%
for var in numerical_feats:
    data = pd.concat([y_train, X_train[var]], axis=1)
    data.plot.scatter(x=var, y='Audit_Risk', ylim=(0,1000));
# Out:
# /home/sanjay/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
ind=X_train[(y_train>800) & (X_train['Risk_A']<15)].index

# %%
X_train = X_train.drop(ind)
y_train = y_train.drop(ind)
y_train1=y_train1.drop(ind)

# %%
for var in numerical_feats:
    data = pd.concat([y_train, X_train[var]], axis=1)
    data.plot.scatter(x=var, y='Audit_Risk', ylim=(0,1000));

# %%
for var in numerical_feats:
    print(var)
    print(X_train[var].unique())
# Out:
# SCORE_A
# [2 6 4]
# SCORE_B
# [2 6 4]
# Marks
# [2 4 6]
# MONEY_Marks
# [2 6 4]
# District
# [2 4 6]
# Loss
# [0 1 2]
# LOSS_SCORE
# [2 4 6]
# History_score
# [2 4 6]
# Sector_score
# [ 2.37  3.89 55.57  1.85  2.72 59.85 21.61  1.99  3.41 15.56  2.34  2.36]
# PARA_A
# [0.000e+00 2.630e+00 2.000e-02 6.400e-01 4.100e-01 3.620e+00 3.000e-02
#  4.400e-01 5.703e+01 1.636e+01 1.079e+01 1.080e+00 1.810e+00 3.900e-01
#  1.268e+01 1.500e-01 8.400e-01 7.400e-01 1.260e+00 5.600e-01 1.002e+01
#  6.500e-01 2.180e+00 3.740e+00 1.000e-02 2.700e-01 4.523e+01 7.700e-01
#  5.200e-01 5.400e-01 5.220e+00 1.140e+00 8.200e-01 2.500e-01 4.250e+00
#  7.600e-01 5.370e+00 3.200e-01 5.100e-01 2.900e-01 1.690e+00 1.538e+01
#  1.400e-01 2.700e+00 1.700e-01 3.800e-01 7.370e+00 1.010e+00 6.100e-01
#  6.800e-01 1.050e+00 1.660e+00 7.200e+00 1.950e+00 1.000e-01 1.130e+00
#  1.270e+00 1.030e+00 1.850e+00 3.170e+00 1.710e+00 1.540e+00 2.000e-01
#  3.980e+00 1.510e+00 5.310e+00 2.840e+00 4.200e-01 9.000e-01 7.010e+00
# ...

# %%
nominal_features=['Marks','MONEY_Marks','District','Loss','LOSS_SCORE','History_score','Score_A','Score_B','numbers',
                 'Score_B.1','Risk_C','Score_MV','District_Loss','PROB','RiSk_E','History','Prob',
                 'Risk_F','Score','CONTROL_RISK','Detection_Risk']
num_features=['PARA_A','PARA_B','Risk_A','Risk_B','TOTAL','Money_Value','Risk_D','Inherent_Risk']

# %%
from scipy import stats
from scipy.stats import norm
for var in numerical_feats:
    sns.regplot(X_train[var], y_train)
    stp = stats.pearsonr(X_train[var], y_train)
    str_title = "r = " + "{0:.2f}".format(stp[0]) + "      " "p = " + "{0:.2f}".format(stp[1])
    fig = plt.figure()
    fig.suptitle(str_title,fontsize=11)
    plt.show()
# Out:
# /home/sanjay/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /home/sanjay/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
names=[]
correlation=[]
for var in numerical_feats:
    stp = stats.pearsonr(X_train[var], y_train)
    names.append(var)
    correlation.append(stp[0])
names=pd.DataFrame(names)
correlation=pd.DataFrame(correlation)
let=pd.concat([names,correlation],axis=1)
let.columns=['a','b']
let.sort_values(['b'], ascending=False)
# Out:
#                  a         b
# 26   Inherent_Risk  0.722565
# 17     Money_Value  0.668458
# 19          Risk_D  0.668144
# 7    History_score  0.613412
# 23            Prob  0.613412
# 27    CONTROL_RISK  0.569844
# 25           Score  0.532580
# 22         History  0.514123
# 24          Risk_F  0.497318
# 13           TOTAL  0.494439
# 3      MONEY_Marks  0.486179
# 18        Score_MV  0.486179
# 12          Risk_B  0.465204
# 11          PARA_B  0.464723
# 15       Score_B.1  0.424339
# 2            Marks  0.424339
# 10          Risk_A  0.421203
# 9           PARA_A  0.419608
# 16          Risk_C  0.418798
# 14         numbers  0.373076
# 21          RiSk_E  0.342730
# 0          SCORE_A  0.341336
# 1          SCORE_B  0.324507
# 4         District  0.296632
# 20            PROB  0.188451
# 6       LOSS_SCORE  0.188451
# 5             Loss  0.125359
# 8     Sector_score -0.140941
# 28  Detection_Risk       NaN

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(20,18))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(x1.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
#as we can see there's lot of multicollinearity and we have to do feature selection

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=2, solver="cholesky")
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=2, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='cholesky', tol=0.001)

# %%
lis_44=ridge_reg.coef_
lis_55=X_train.columns
lis_44=pd.DataFrame(lis_44)
lis_55=pd.DataFrame(lis_55)
lis_66=pd.concat([lis_44,lis_55],axis=1)
lis_66.columns=(['a','b'])
lis_66.sort_values(['a'], ascending=False)
# Out:
#             a               b
# 28  11.518779    CONTROL_RISK
# 7    9.804624   History_score
# 25   9.468918          Risk_F
# 6    6.643764      LOSS_SCORE
# 10   4.751453          PARA_A
# 12   3.893955          PARA_B
# 27   2.395942   Inherent_Risk
# 17   2.216509          Risk_C
# 22   2.049862          RiSk_E
# 26   0.986765           Score
# 24   0.980462            Prob
# 21   0.664376            PROB
# 3    0.212276     MONEY_Marks
# 0    0.198189         SCORE_A
# 8    0.053007    Sector_score
# 19   0.021228        Score_MV
# 29   0.000000  Detection_Risk
# 9   -0.061192     LOCATION_ID
# 16  -0.182943       Score_B.1
# 18  -0.369661     Money_Value
# 15  -0.555700         numbers
# 13  -0.675907          Risk_B
# 4   -0.804595        District
# 1   -0.842583         SCORE_B
# 20  -1.508326          Risk_D
# 2   -1.829427           Marks
# 11  -2.091986          Risk_A
# 14  -4.780913           TOTAL
# 23 -12.599136         History
# 5  -16.764705            Loss

# %%
#try values for alpha and negative sign of cofficients here shows multicollinearity

# %%
drop1=['Risk_A','Risk_B','Risk_C','Risk_D','RiSk_E','Risk_F']
for var in drop1:
    del X_train[var]
    del X_test[var]

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=1, solver="cholesky")
ridge_reg.fit(X_train, y_train)
lis_44=ridge_reg.coef_
lis_55=X_train.columns
lis_44=pd.DataFrame(lis_44)
lis_55=pd.DataFrame(lis_55)
lis_66=pd.concat([lis_44,lis_55],axis=1)
lis_66.columns=(['a','b'])
lis_66.sort_values(['a'], ascending=False)
# Out:
#             a               b
# 22  19.516094    CONTROL_RISK
# 7   10.011460   History_score
# 6    9.860892      LOSS_SCORE
# 10   4.351560          PARA_A
# 11   4.343512          PARA_B
# 20   1.483849           Score
# 13   1.192643         numbers
# 21   1.106598   Inherent_Risk
# 19   1.001146            Prob
# 17   0.986089            PROB
# 0    0.129121         SCORE_A
# 3    0.125322     MONEY_Marks
# 8    0.053829    Sector_score
# 16   0.012532        Score_MV
# 23   0.000000  Detection_Risk
# 14  -0.026763       Score_B.1
# 9   -0.062036     LOCATION_ID
# 2   -0.267625           Marks
# 15  -0.502098     Money_Value
# 1   -0.960169         SCORE_B
# 4   -1.872543        District
# 12  -4.858549           TOTAL
# 18 -11.553141         History
# 5  -26.102091            Loss

# %%
drop2=['District','LOCATION_ID']
for var in drop2:
    del X_train[var]
    del X_test[var]

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=1, solver="cholesky")
ridge_reg.fit(X_train, y_train)
lis_44=ridge_reg.coef_
lis_55=X_train.columns
lis_44=pd.DataFrame(lis_44)
lis_55=pd.DataFrame(lis_55)
lis_66=pd.concat([lis_44,lis_55],axis=1)
lis_66.columns=(['a','b'])
lis_66.sort_values(['a'], ascending=False)
# Out:
#             a               b
# 20  14.981180    CONTROL_RISK
# 5   12.192430      LOSS_SCORE
# 6   10.505956   History_score
# 8    4.290312          PARA_A
# 9    4.287746          PARA_B
# 2    1.367997           Marks
# 15   1.219243            PROB
# 1    1.185476         SCORE_B
# 19   1.065419   Inherent_Risk
# 17   1.050596            Prob
# 11   1.008790         numbers
# 0    0.836148         SCORE_A
# 3    0.738906     MONEY_Marks
# 12   0.136800       Score_B.1
# 14   0.073891        Score_MV
# 7    0.054509    Sector_score
# 21   0.000000  Detection_Risk
# 13  -0.475165     Money_Value
# 10  -4.778752           TOTAL
# 18  -5.776879           Score
# 16  -8.546058         History
# 4  -26.869528            Loss

# %%
numerical_feats=X_train.columns

# %%
names=[]
correlation=[]
for var in numerical_feats:
    stp = stats.pearsonr(X_train[var], y_train)
    names.append(var)
    correlation.append(stp[0])
names=pd.DataFrame(names)
correlation=pd.DataFrame(correlation)
let=pd.concat([names,correlation],axis=1)
let.columns=['a','b']
let.sort_values(['b'], ascending=False)
# Out:
# /home/sanjay/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
#                  a         b
# 19   Inherent_Risk  0.722565
# 13     Money_Value  0.668458
# 17            Prob  0.613412
# 6    History_score  0.613412
# 20    CONTROL_RISK  0.569844
# 18           Score  0.532580
# 16         History  0.514123
# 10           TOTAL  0.494439
# 3      MONEY_Marks  0.486179
# 14        Score_MV  0.486179
# 9           PARA_B  0.464723
# 12       Score_B.1  0.424339
# 2            Marks  0.424339
# 8           PARA_A  0.419608
# 11         numbers  0.373076
# 0          SCORE_A  0.341336
# 1          SCORE_B  0.324507
# 15            PROB  0.188451
# 5       LOSS_SCORE  0.188451
# 4             Loss  0.125359
# 7     Sector_score -0.140941
# 21  Detection_Risk       NaN

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(10,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(X_train.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
drop3=['numbers','Score_B.1','Score_MV','PROB','Money_Value','Prob']
for var in drop3:
    del X_train[var]
    del X_test[var]

# %%
numerical_feats=X_train.columns

# %%
names=[]
correlation=[]
for var in numerical_feats:
    stp = stats.pearsonr(X_train[var], y_train)
    names.append(var)
    correlation.append(stp[0])
names=pd.DataFrame(names)
correlation=pd.DataFrame(correlation)
let=pd.concat([names,correlation],axis=1)
let.columns=['a','b']
let.sort_values(['b'], ascending=False)
# Out:
#                  a         b
# 13   Inherent_Risk  0.722565
# 6    History_score  0.613412
# 14    CONTROL_RISK  0.569844
# 12           Score  0.532580
# 11         History  0.514123
# 10           TOTAL  0.494439
# 3      MONEY_Marks  0.486179
# 9           PARA_B  0.464723
# 2            Marks  0.424339
# 8           PARA_A  0.419608
# 0          SCORE_A  0.341336
# 1          SCORE_B  0.324507
# 5       LOSS_SCORE  0.188451
# 4             Loss  0.125359
# 7     Sector_score -0.140941
# 15  Detection_Risk       NaN

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(10,10))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(X_train.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)

# %%
del X_train['Detection_Risk']
del X_test['Detection_Risk']

# %%
X_train.columns
# Out:
# Index(['SCORE_A', 'SCORE_B', 'Marks', 'MONEY_Marks', 'Loss', 'LOSS_SCORE',
#        'History_score', 'Sector_score', 'PARA_A', 'PARA_B', 'TOTAL', 'History',
#        'Score', 'Inherent_Risk', 'CONTROL_RISK'],
#       dtype='object')

# %%
del X_train['SCORE_A']
del X_test['SCORE_A']

# %%
del X_train['CONTROL_RISK']
del X_test['CONTROL_RISK']

# %%
del X_train['Inherent_Risk']
del X_test['Inherent_Risk']

# %%
X_train.columns
# Out:
# Index(['SCORE_B', 'Marks', 'MONEY_Marks', 'Loss', 'LOSS_SCORE',
#        'History_score', 'Sector_score', 'PARA_A', 'PARA_B', 'TOTAL', 'History',
#        'Score'],
#       dtype='object')

# %%
X_train.head()
# Out:
#      SCORE_B  Marks  MONEY_Marks  Loss  LOSS_SCORE  History_score  \
# 335        2      2            2     0           2              2
# 110        2      2            2     0           2              2
# 82         2      2            2     0           2              2
# 51         6      2            2     0           2              2
# 763        2      2            2     0           2              2
#
#      Sector_score  PARA_A  PARA_B  TOTAL  History  Score
# 335          2.37    0.00    0.00   0.00        0    2.0
# 110          3.89    2.63    2.55   5.18        0    2.4
# 82           3.89    0.00    0.00   0.00        0    2.0
# 51           3.89    0.00   18.05  18.05        0    3.2
# 763         55.57    0.02    0.00   0.02        0    2.0

# %%
drop4=['History','Loss','TOTAL','SCORE_B','Score']
for var in drop4:
    del X_train[var]
    del X_test[var]

# %%
X_train.head()
# Out:
#      Marks  MONEY_Marks  LOSS_SCORE  History_score  Sector_score  PARA_A  \
# 335      2            2           2              2          2.37    0.00
# 110      2            2           2              2          3.89    2.63
# 82       2            2           2              2          3.89    0.00
# 51       2            2           2              2          3.89    0.00
# 763      2            2           2              2         55.57    0.02
#
#      PARA_B
# 335    0.00
# 110    2.55
# 82     0.00
# 51    18.05
# 763    0.00

# %%
from sklearn.preprocessing import StandardScaler
import numpy as np
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
# Out:
# /home/sanjay/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/sanjay/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# /home/sanjay/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /home/sanjay/anaconda3/lib/python3.7/site-packages/sklearn/base.py:462: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0, solver="cholesky")
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='cholesky', tol=0.001)

# %%
y_pred1=ridge_reg.predict(X_train)
y_pred3=ridge_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_pred1)
# Out:
# 0.5554071762117196

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.2668970504191853

# %%
sns.distplot(y_train,fit=norm)
plt.figure()
res=stats.probplot(y_train,plot=plt)
# Out:
# /home/sanjay/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#now we can see why we are getting poor results our y_train(target is not normally distributed)

# %%
y_train=np.log1p(y_train)

# %%
sns.distplot(y_train,fit=norm)
plt.figure()
res=stats.probplot(y_train,plot=plt)

# %%
y_test=np.log1p(y_test)

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0, solver="cholesky")
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='cholesky', tol=0.001)

# %%
y_pred1=ridge_reg.predict(X_train)
y_pred=ridge_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_train,y_pred1)
# Out:
# 0.8868340294035276

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7835399017818925

# %%
#as we can see huge change in accuracy after log transformation of y(dependent variable)
#as distribution of Y wasn't normally distributed,and that was violation of Linear regression assumptions 
#that's why we were getting poor results

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.metrics import mean_squared_error, make_scorer
from scipy.stats import skew
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

scorer = make_scorer(mean_squared_error, greater_is_better = False)

def rmse_cv_train(model):
    rmse= np.sqrt(-cross_val_score(model, train, y_train, scoring = scorer, cv = 10))
    return(rmse)

def rmse_cv_test(model):
    rmse= np.sqrt(-cross_val_score(model, test, y_test, scoring = scorer, cv = 10))
    return(rmse)

# %%
ridge = RidgeCV(alphas = [0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6, 10, 30, 60])
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("Best alpha :", alpha)

print("Try again for more precision with alphas centered around " + str(alpha))
ridge = RidgeCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, alpha * .85, 
                          alpha * .9, alpha * .95, alpha, alpha * 1.05, alpha * 1.1, alpha * 1.15,
                          alpha * 1.25, alpha * 1.3, alpha * 1.35, alpha * 1.4], 
                cv = 10)
ridge.fit(X_train, y_train)
alpha = ridge.alpha_
print("Best alpha :", alpha)
# Out:
# Best alpha : 30.0
# Try again for more precision with alphas centered around 30.0
# Best alpha : 28.5

# %%
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=28.5, solver="cholesky")
ridge_reg.fit(X_train, y_train)
# Out:
# Ridge(alpha=28.5, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=False, random_state=None, solver='cholesky', tol=0.001)

# %%
y_pred2=ridge_reg.predict(X_train)
y_pred3=ridge_reg.predict(X_test)

# %%
r2_score(y_train,y_pred2)
# Out:
# 0.8862098859147008

# %%
r2_score(y_test,y_pred3)
# Out:
# 0.786880395988568

# %%
lasso = LassoCV(alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 
                          0.3, 0.6, 1], 
                max_iter = 50000, cv = 10)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("Best alpha :", alpha)

print("Try again for more precision with alphas centered around " + str(alpha))
lasso = LassoCV(alphas = [alpha * .6, alpha * .65, alpha * .7, alpha * .75, alpha * .8, 
                          alpha * .85, alpha * .9, alpha * .95, alpha, alpha * 1.05, 
                          alpha * 1.1, alpha * 1.15, alpha * 1.25, alpha * 1.3, alpha * 1.35, 
                          alpha * 1.4], 
                max_iter = 50000, cv = 10)
lasso.fit(X_train, y_train)
alpha = lasso.alpha_
print("Best alpha :", alpha)
# Out:
# Best alpha : 0.006
# Try again for more precision with alphas centered around 0.006
# Best alpha : 0.0054

# %%
y_pred4=lasso.predict(X_train)
y_pred5=lasso.predict(X_test)

# %%
r2_score(y_train,y_pred4)
# Out:
# 0.8867593703509431

# %%
elasticNet = ElasticNetCV(l1_ratio = [0.1, 0.3, 0.5, 0.6, 0.7, 0.8, 0.85, 0.9, 0.95, 1],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 
                                    0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
elasticNet.fit(X_train, y_train)
alpha = elasticNet.alpha_
ratio = elasticNet.l1_ratio_
print("Best l1_ratio :", ratio)
print("Best alpha :", alpha )

print("Try again for more precision with l1_ratio centered around " + str(ratio))
elasticNet = ElasticNetCV(l1_ratio = [ratio * .85, ratio * .9, ratio * .95, ratio, ratio * 1.05, ratio * 1.1, ratio * 1.15],
                          alphas = [0.0001, 0.0003, 0.0006, 0.001, 0.003, 0.006, 0.01, 0.03, 0.06, 0.1, 0.3, 0.6, 1, 3, 6], 
                          max_iter = 50000, cv = 10)
elasticNet.fit(X_train, y_train)
if (elasticNet.l1_ratio_ > 1):
    elasticNet.l1_ratio_ = 1    
alpha = elasticNet.alpha_
ratio = elasticNet.l1_ratio_
print("Best l1_ratio :", ratio)
print("Best alpha :", alpha )
# Out:
# Best l1_ratio : 0.1
# Best alpha : 0.03
# Try again for more precision with l1_ratio centered around 0.1
# Best l1_ratio : 0.085
# Best alpha : 0.03

# %%
y_pred4=elasticNet.predict(X_train)
y_pred5=elasticNet.predict(X_test)

# %%
r2_score(y_train,y_pred4)
# Out:
# 0.8865800178290454

# %%
r2_score(y_test,y_pred5)
# Out:
# 0.7860219856980292

# %%
#maximum achievable r2 using regularization on test set is .78

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear',C=1)
svc.fit(X_train,y_train1)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred4=svc.predict(X_train)
y_pred5=svc.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test1, y_pred5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       141
#            1       0.91      0.80      0.86        92
#
#    micro avg       0.89      0.89      0.89       233
#    macro avg       0.90      0.88      0.89       233
# weighted avg       0.89      0.89      0.89       233

# %%
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test1, y_pred5)

# %%
mat
# Out:
# array([[134,   7],
#        [ 18,  74]])

# %%
#total 25 misclassifications at c=1
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test1, y_pred5))
# Out:
# Accuracy: 0.8927038626609443

# %%
from sklearn.svm import SVC
svc = SVC(kernel='poly',C=1000,degree=3)
svc.fit(X_train,y_train1)
# Out:
# SVC(C=1000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='poly', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred4=svc.predict(X_train)
y_pred5=svc.predict(X_test)

# %%
mat = confusion_matrix(y_test1, y_pred5)

# %%
mat
# Out:
# array([[135,   6],
#        [ 19,  73]])

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test1, y_pred5))
#at hard margin polynomial gives good results but almost similar to linear
# Out:
# Accuracy: 0.8927038626609443

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=7)
model.fit(X_train,y_train1)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#            weights='uniform')

# %%
y_pred4=model.predict(X_train)
y_pred5=model.predict(X_test)

# %%
mat = confusion_matrix(y_test1, y_pred5)

# %%
mat
# Out:
# array([[133,   8],
#        [ 17,  75]])

# %%
#try different values for no of neighbours you want to consider

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test1, y_pred5))
# Out:
# Accuracy: 0.8927038626609443

# %%
#as you can see accuracy is same but you can also use confusion metrics to check no of missclassified instances
#
